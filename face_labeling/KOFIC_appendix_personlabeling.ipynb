# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

KOBIS_API_KEY = os.getenv("KOBIS_API_KEY")

API_MOVIE_LIST = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"
API_MOVIE_INFO = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json"
API_PEOPLE_LIST = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleList.json"

PEOPLE_PAGE = "https://www.kobis.or.kr/kobis/business/mast/mvie/searchMovieList.do"

session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0 (compatible; KOBIS-crawler/1.0)"
})

# %%
def get_movie_cd(movie_name: str) -> str | None:
    """영화명으로 movieCd(영화코드) 가져오기"""
    params = {
        "key": KOBIS_API_KEY,
        "movieNm": movie_name,
        "itemPerPage": 10,
    }
    r = session.get(API_MOVIE_LIST, params=params)
    r.raise_for_status()
    data = r.json()
    movies = data.get("movieListResult", {}).get("movieList", [])
    if not movies:
        return None

    # 가장 첫 번째 결과 사용 (필요하면 prdtYear, 국가 등으로 추가 필터링)
    return movies[0]["movieCd"]


def get_main_actors(movie_cd: str, max_actors: int = 10) -> list[dict]:
    """movieCd로 영화 상세에서 배우 목록 중 상위 max_actors명을 '주연'처럼 사용"""
    params = {"key": KOBIS_API_KEY, "movieCd": movie_cd}
    r = session.get(API_MOVIE_INFO, params=params)
    r.raise_for_status()
    data = r.json()

    movie_info = data["movieInfoResult"]["movieInfo"]
    actors = movie_info.get("actors", [])

    # KOBIS API는 '주연/조연' 구분이 없으므로, 상위 N명을 대표 배우로 사용
    return actors[:max_actors]


def get_people_cd(actor_name: str, movie_name: str, prefer_role: str = "배우") -> str | None:
    params = {
        "key": KOBIS_API_KEY,
        "peopleNm": actor_name,
        "filmoNames": movie_name,
        "itemPerPage": 10,
    }
    r = session.get(API_PEOPLE_LIST, params=params)
    r.raise_for_status()
    data = r.json()

    people_list = data.get("peopleListResult", {}).get("peopleList", [])
    if not people_list:
        return None

    # 1순위: 영화 제목이 filmoNames에 포함되고, 대표분야가 '배우' 인 사람
    candidates = [
        p for p in people_list
        if movie_name in (p.get("filmoNames") or "")
        and p.get("repRoleNm") == prefer_role
    ]

    # 2순위: 대표분야만 '배우' 인 사람
    if not candidates:
        candidates = [
            p for p in people_list
            if p.get("repRoleNm") == prefer_role
        ]

    # else => 그냥 첫 번째
    if not candidates:
        candidates = people_list

    chosen = candidates[0]
    """
    print(
        f"[get_people_cd] 선택: {chosen.get('peopleNm')} / "
        f"{chosen.get('repRoleNm')} / peopleCd={chosen.get('peopleCd')}"
    )
    """
    return chosen["peopleCd"]

def get_actor_images_from_people_page(people_cd: str) -> list[str]:
    """
    영화인 코드(peopleCd)로 KOBIS 모바일 영화인 상세 페이지를 가져와서
    사람 사진(/common/mast/people/) URL들을 추출.
    """
    DETAIL_URL = "https://www.kobis.or.kr/kobis/mobile/mast/peop/searchPeopleDtl.do"

    params = {"peopleCd": people_cd}
    r = session.get(DETAIL_URL, params=params)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")

    image_urls: list[str] = []

    # 페이지 안의 모든 img 중 사람 사진 경로만 수집
    for img in soup.find_all("img"):
        src = img.get("src") or ""
        if "/common/mast/people/" not in src:
            continue
        full = urljoin(r.url, src)
        if full not in image_urls:
            image_urls.append(full)

    return image_urls

def get_main_actor_images(movie_name: str) -> dict[str, dict[str, str]]:
    """
    영화명 → 배우 → (배역 이름 + 대표 이미지 1장 URL)
    리턴 예시:
    {
        "송강호": {
            "cast": "김기택",
            "image_url": "https://....jpg"
        },
        ...
    }
    """
    movie_cd = get_movie_cd(movie_name)
    if not movie_cd:
        raise ValueError(f"영화명을 찾을 수 없음: {movie_name}")

    # KOBIS movieInfo API에서 배우 목록 가져오기
    main_actors = get_main_actors(movie_cd)
    result: dict[str, dict[str, str]] = {}

    for actor in main_actors:
        name = actor["peopleNm"]               # 배우 이름
        cast = actor.get("cast", "") or ""     # 등장인물 이름(배역명), 없으면 빈 문자열

        print(f"[+] 주연 배우 처리 중: {name} / 배역: {cast}")

        # 배우 + 영화 제목으로 peopleCd 찾기
        people_cd = get_people_cd(name, movie_name)
        if not people_cd:
            print(f"    -> peopleCd를 찾지 못했습니다.")
            continue

        # 영화인 상세 페이지에서 인물 사진 URL 리스트 추출
        img_urls = get_actor_images_from_people_page(people_cd)
        if not img_urls:
            print(f"    -> 배우 사진 URL을 찾지 못했습니다.")
            continue

        # 첫 번째 이미지를 대표 사진으로 사용
        result[name] = {
            "cast": cast,
            "image_url": img_urls[0],
        }

    return result

# %%
movie_title = "기생충"
images_by_actor = get_main_actor_images(movie_title)
print(images_by_actor)
# Out:
# [+] 주연 배우 처리 중: 송강호 / 배역: 기택
# [+] 주연 배우 처리 중: 이선균 / 배역: 동익
# [+] 주연 배우 처리 중: 조여정 / 배역: 연교
# [+] 주연 배우 처리 중: 최우식 / 배역: 기우
# [+] 주연 배우 처리 중: 박소담 / 배역: 기정
# [+] 주연 배우 처리 중: 이정은 / 배역: 문광
# [+] 주연 배우 처리 중: 장혜진 / 배역: 충숙
# [+] 주연 배우 처리 중: 박명훈 / 배역: 근세
# [+] 주연 배우 처리 중: 정지소 / 배역: 다혜
# [+] 주연 배우 처리 중: 정현준 / 배역: 다송
# {'송강호': {'cast': '기택', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2017/07/thumb_x110/thn_212ae19d375049fa86ffa72bed520a28.jpg'}, '이선균': {'cast': '동익', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/09/thumb_x110/thn_0891637b67014d9a9d6b47556c2ad355.jpg'}, '조여정': {'cast': '연교', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2020/02/thumb_x110/thn_352368f0358b4932974e3578330679a6.jpg'}, '최우식': {'cast': '기우', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2020/01/thumb_x110/thn_1f768834f6834c75b9249328e69a18a9.jpg'}, '박소담': {'cast': '기정', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/10/thumb_x110/thn_489ac59594a84cbf8f6d76238f97fbf2.jpg'}, '이정은': {'cast': '문광', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/09/thumb_x110/thn_1f1cabe146a447a2ad884656752c7114.jpg'}, '장혜진': {'cast': '충숙', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/04/thumb_x110/thn_2497de762f914cd7a61204bb4ec7df62.jpg'}, '박명훈': {'cast': '근세', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/10/thumb_x110/thn_c7f78649f03749fba8fe43e227a07e71.jpg'}, '정지소': {'cast': '다혜', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/06/thumb_x110/thn_007425dddfe8420b85700cd13b3a9856.jpg'}, '정현준': {'cast': '다송', 'image_url': 'https://www.kobis.or.kr/common/mast/people/2019/11/thumb_x110/thn_800a891870f645cbbe1c2be74d660fd0.jpg'}}

# %%
import os

os.makedirs("actor_images", exist_ok=True)

movie_title = "기생충"
actors_info = get_main_actor_images(movie_title)
# actors_info: {배우이름: {"cast": 배역명, "image_url": ...}}

for actor, info in actors_info.items():
    cast = info.get("cast", "")
    url = info["image_url"]

    resp = session.get(url)
    resp.raise_for_status()

    ext = os.path.splitext(url)[1] or ".jpg"

    # 파일 = 배우 이름 + 배역명 / 예: 송강호_김기택.jpg
    safe_actor = actor.replace(" ", "_")
    safe_cast = cast.replace(" ", "_") if cast else ""
    if safe_cast:
        filename = f"actor_images/{safe_actor}_{safe_cast}{ext}"
    else:
        filename = f"actor_images/{safe_actor}{ext}"

    with open(filename, "wb") as f:
        f.write(resp.content)

    print(f"saved: {filename} (배우: {actor}, 배역: {cast})")
# Out:
# [+] 주연 배우 처리 중: 송강호 / 배역: 기택
# [+] 주연 배우 처리 중: 이선균 / 배역: 동익
# [+] 주연 배우 처리 중: 조여정 / 배역: 연교
# [+] 주연 배우 처리 중: 최우식 / 배역: 기우
# [+] 주연 배우 처리 중: 박소담 / 배역: 기정
# [+] 주연 배우 처리 중: 이정은 / 배역: 문광
# [+] 주연 배우 처리 중: 장혜진 / 배역: 충숙
# [+] 주연 배우 처리 중: 박명훈 / 배역: 근세
# [+] 주연 배우 처리 중: 정지소 / 배역: 다혜
# [+] 주연 배우 처리 중: 정현준 / 배역: 다송
# saved: actor_images/송강호_기택.jpg (배우: 송강호, 배역: 기택)
# saved: actor_images/이선균_동익.jpg (배우: 이선균, 배역: 동익)
# saved: actor_images/조여정_연교.jpg (배우: 조여정, 배역: 연교)
# saved: actor_images/최우식_기우.jpg (배우: 최우식, 배역: 기우)
# saved: actor_images/박소담_기정.jpg (배우: 박소담, 배역: 기정)
# saved: actor_images/이정은_문광.jpg (배우: 이정은, 배역: 문광)
# saved: actor_images/장혜진_충숙.jpg (배우: 장혜진, 배역: 충숙)
# saved: actor_images/박명훈_근세.jpg (배우: 박명훈, 배역: 근세)
# saved: actor_images/정지소_다혜.jpg (배우: 정지소, 배역: 다혜)
# saved: actor_images/정현준_다송.jpg (배우: 정현준, 배역: 다송)

# %% [markdown]
# Appendix person labeling

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install insightface onnxruntime-gpu opencv-python
# Out:
# Mounted at /content/drive
# Collecting insightface
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.2)
# Collecting onnx (from insightface)
#   Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from insightface) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from insightface) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from insightface) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from insightface) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from insightface) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from insightface) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from insightface) (0.25.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from insightface) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from insightface) (3.0.12)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.8)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from insightface) (3.17.0)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.9.23)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.14.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (4.2.3)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (6.5.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (0.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->insightface) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2025.11.12)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (3.6)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.17.0)
# Downloading onnxruntime_gpu-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (300.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 MB 4.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.8 MB/s eta 0:00:00
# Downloading onnx-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 57.4 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.6 MB/s eta 0:00:00
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml) ... done
#   Created wheel for insightface: filename=insightface-0.7.3-cp312-cp312-linux_x86_64.whl size=1071343 sha256=d657be3ee994ce7888128f799e807ea6a793b70dd122cb20cfa8ade302b4a4ac
#   Stored in directory: /root/.cache/pip/wheels/73/3c/e2/6d4815e8a8b33a2006554d65ce0d1f973e768f4c7a222fa675
# Successfully built insightface
# Installing collected packages: humanfriendly, onnx, coloredlogs, onnxruntime-gpu, insightface
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 insightface-0.7.3 onnx-1.19.1 onnxruntime-gpu-1.23.2

# %%
import cv2
import json
import numpy as np
from pathlib import Path
from insightface.app import FaceAnalysis

# 얼굴 검출 + 인식 모델
app = FaceAnalysis(
    name='buffalo_l',
    root='/content/insightface_model',       # 모델 캐시 경로
    allowed_modules=['detection', 'recognition']
)
app.prepare(
    ctx_id=0,            # GPU 사용 시 0, CPU만 사용이면 -1
    det_size=(640, 640)  # 입력 이미지 리사이즈 기준
)
# Out:
# download_path: /content/insightface_model/models/buffalo_l
# Downloading /content/insightface_model/models/buffalo_l.zip from https://github.com/deepinsight/insightface/releases/download/v0.7/buffalo_l.zip...
# 100%|██████████| 281857/281857 [00:05<00:00, 56343.86KB/s]
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=a33fec4e780e ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /content/insightface_model/models/buffalo_l/1k3d68.onnx landmark_3d_68
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=a33fec4e780e ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /content/insightface_model/models/buffalo_l/2d106det.onnx landmark_2d_106
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=a33fec4e780e ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /content/insightface_model/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=a33fec4e780e ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: /content/insightface_model/models/buffalo_l/genderage.onnx genderage
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=a33fec4e780e ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /content/insightface_model/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
ACTOR_DIR = Path("/content/actor_images")

def get_first_face_embedding(img_path: Path, app: FaceAnalysis):
    """이미지에서 첫 번째 얼굴 임베딩 1개만 추출"""
    img = cv2.imread(str(img_path))
    if img is None:
        print(f"[WARN] 이미지 로드 실패: {img_path}")
        return None

    faces = app.get(img)
    if len(faces) == 0:
        print(f"[WARN] 얼굴을 찾지 못함: {img_path}")
        return None

    emb = faces[0].normed_embedding  # (D,)
    return emb

gallery_embeddings = []
gallery_actor_labels = []  # 배우 이름
gallery_cast_labels  = []  # 배역 이름

for img_file in sorted(ACTOR_DIR.glob("*.jpg")):
    stem = img_file.stem        # 예: '송강호_기택'

    # 파일명에서 배우 / 배역 분리
    if "_" in stem:
        actor_name, cast_name = stem.split("_", 1)
    else:
        actor_name, cast_name = stem, ""   # 혹시 _ 없는 경우 대비

    emb = get_first_face_embedding(img_file, app)
    if emb is None:
        continue

    emb = emb / np.linalg.norm(emb)
    gallery_embeddings.append(emb)
    gallery_actor_labels.append(actor_name)
    gallery_cast_labels.append(cast_name)

gallery_embeddings = np.vstack(gallery_embeddings)   # (N, D)

np.save("/content/gallery_embeddings.npy", gallery_embeddings)
with open("/content/gallery_actor_labels.json", "w", encoding="utf-8") as f:
    json.dump(gallery_actor_labels, f, ensure_ascii=False, indent=2)
with open("/content/gallery_cast_labels.json", "w", encoding="utf-8") as f:
    json.dump(gallery_cast_labels, f, ensure_ascii=False, indent=2)

print("등장인물 DB 인원 수:", len(gallery_actor_labels))
print("배우 라벨:", gallery_actor_labels)
print("배역 라벨:", gallery_cast_labels)
# Out:
# 등장인물 DB 인원 수: 10
# 배우 라벨: ['박명훈', '박소담', '송강호', '이선균', '이정은', '장혜진', '정지소', '정현준', '조여정', '최우식']
# 배역 라벨: ['근세', '기정', '기택', '동익', '문광', '충숙', '다혜', '다송', '연교', '기우']

# %%
def match_embedding_to_gallery(face_emb,
                               gallery_embeddings,
                               gallery_actor_labels,
                               gallery_cast_labels,
                               sim_threshold=0.5):
    sims = gallery_embeddings @ face_emb  # (N,)
    best_idx = int(np.argmax(sims))
    best_sim = float(sims[best_idx])

    best_actor = gallery_actor_labels[best_idx]
    best_cast  = gallery_cast_labels[best_idx]

    if best_sim < sim_threshold:
        return "Unknown", "", best_sim   # 배우 Unknown, 배역은 빈 문자열
    return best_actor, best_cast, best_sim

# %%
def label_faces_in_thumbnail(img_path: Path,
                             app: FaceAnalysis,
                             gallery_embeddings: np.ndarray,
                             gallery_actor_labels,
                             gallery_cast_labels,
                             sim_threshold: float = 0.2):
    img = cv2.imread(str(img_path))
    if img is None:
        print(f"[WARN] 썸네일 로드 실패: {img_path}")
        return []

    faces = app.get(img)
    results = []

    for i, f in enumerate(faces):
        emb = f.normed_embedding
        emb = emb / np.linalg.norm(emb)

        bbox = f.bbox  # [x1, y1, x2, y2]
        actor_label, cast_label, sim = match_embedding_to_gallery(
            emb,
            gallery_embeddings,
            gallery_actor_labels,
            gallery_cast_labels,
            sim_threshold
        )

        results.append({
            "face_id": i,
            "bbox": [float(bbox[0]), float(bbox[1]), float(bbox[2]), float(bbox[3])],
            "actor": actor_label,
            "cast": cast_label,
            "similarity": sim
        })

    return results

# %%
THUMB_DIR = Path("/content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/split_scenes/thumbnails_2")

import csv

output_rows = []

for img_file in sorted(THUMB_DIR.glob("*.jpg")):
    shot_id = img_file.stem           # 예: '001', '002', ...
    faces_info = label_faces_in_thumbnail(
        img_file,
        app,
        gallery_embeddings,
        gallery_actor_labels,
        gallery_cast_labels,
        sim_threshold=0.2
    )

    for face_info in faces_info:
        x1, y1, x2, y2 = face_info["bbox"]
        w = x2 - x1
        h = y2 - y1

        output_rows.append([
            shot_id,
            face_info["face_id"],
            x1, y1, w, h,
            face_info["actor"],   # 배우 이름
            face_info["cast"],    # 배역 이름
            face_info["similarity"]
        ])

csv_path = "/content/face_labeling_0.2.csv"
with open(csv_path, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow([
        "shot_id", "face_id", "x", "y", "w", "h",
        "actor", "cast", "similarity"
    ])
    writer.writerows(output_rows)

# %%
# Colab 에 나눔폰트 설치
# !apt-get -y install fonts-nanum

from PIL import ImageFont, ImageDraw, Image

# 사용할 한글 폰트 경로 (Colab 기준)
FONT_PATH = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
KOREAN_FONT = ImageFont.truetype(FONT_PATH, 20)  # 글자 크기는 필요에 따라 조절
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,065 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
OUT_DIR = Path("/content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2")
OUT_DIR.mkdir(parents=True, exist_ok=True)

def visualize_one_thumbnail(img_path: Path,
                            app: FaceAnalysis,
                            gallery_embeddings,
                            gallery_actor_labels,
                            gallery_cast_labels,
                            sim_threshold: float = 0.2):
    # 1) 이미지 로드
    img_bgr = cv2.imread(str(img_path))
    if img_bgr is None:
        return

    faces = app.get(img_bgr)
    if not faces:
        out_path = OUT_DIR / img_path.name
        cv2.imwrite(str(out_path), img_bgr)  # 얼굴 없으면 원본 저장
        return out_path

    # 2) OpenCV(BGR) -> Pillow(RGB) 로 변환
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_pil = Image.fromarray(img_rgb)
    draw = ImageDraw.Draw(img_pil)

    # 3) 얼굴마다 bbox + 한글 텍스트 그리기
    for f in faces:
        emb = f.normed_embedding
        emb = emb / np.linalg.norm(emb)
        bbox = f.bbox.astype(int)
        actor_label, cast_label, sim = match_embedding_to_gallery(
            emb,
            gallery_embeddings,
            gallery_actor_labels,
            gallery_cast_labels,
            sim_threshold
        )

        x1, y1, x2, y2 = bbox
        # 박스 (녹색)
        draw.rectangle([(x1, y1), (x2, y2)], outline=(0, 255, 0), width=2)

        # 한글 텍스트
        text = f"{cast_label}({actor_label}) {sim:.2f}"
        text_pos = (x1, max(0, y1 - 25))  # 박스 위쪽에 글자
        draw.text(text_pos, text, font=KOREAN_FONT, fill=(0, 255, 0))

    # 4) 다시 OpenCV(BGR) 로 변환해서 저장
    img_out = cv2.cvtColor(np.array(img_pil), cv2.COLOR_RGB2BGR)
    out_path = OUT_DIR / img_path.name
    cv2.imwrite(str(out_path), img_out)
    return out_path

# 전체 썸네일 시각화 & 드라이브에 저장
for img_file in sorted(THUMB_DIR.glob("*.jpg")):
    print(visualize_one_thumbnail(
        img_file,
        app,
        gallery_embeddings,
        gallery_actor_labels,
        gallery_cast_labels,
        sim_threshold=0.2
    ))
# Out:
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/001.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/002.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/003.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/004.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/005.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/006.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/007.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/008.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/009.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/010.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/011.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/012.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/013.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/014.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/015.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/016.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/017.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/018.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/019.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/020.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/021.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/022.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/023.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/024.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/025.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/026.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/027.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/028.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/029.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/030.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/031.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/032.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/033.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/034.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/035.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/036.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/037.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/038.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/039.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/040.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/041.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/042.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/043.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/044.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/045.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/046.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/047.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/048.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/049.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/050.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/051.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/052.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/053.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/054.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/055.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/056.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/057.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/058.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/059.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/060.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/061.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/062.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/063.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/064.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/065.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/066.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/067.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/068.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/069.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/070.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/071.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/072.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/073.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/074.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/075.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/076.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/077.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/078.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/079.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/080.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/081.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/082.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/083.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/084.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/085.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/086.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/087.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/088.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/089.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/090.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/091.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/092.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/093.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/094.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/095.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/096.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/097.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/098.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/099.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/100.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/101.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/102.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/103.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/104.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/105.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/106.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/107.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/108.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/109.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/110.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/111.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/112.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/113.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/114.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/115.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/116.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/117.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/118.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/119.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/120.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/121.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/122.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/123.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/124.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/125.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/126.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/127.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/128.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/129.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/130.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/131.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/132.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/133.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/134.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/135.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/136.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/137.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/138.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/139.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/140.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/141.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/142.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/143.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/144.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/145.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/146.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/147.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/148.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/149.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/150.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/151.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/152.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/153.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/154.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/155.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/156.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/157.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/158.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/159.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/160.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/161.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/162.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/163.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/164.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/165.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/166.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/167.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/168.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/169.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/170.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/171.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/172.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/173.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/174.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/175.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/176.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/177.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/178.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/179.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/180.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/181.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/182.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/183.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/184.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/185.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/186.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/187.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/188.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/189.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/190.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/191.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/192.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/193.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/194.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/195.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/196.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/197.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/198.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/199.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/200.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/201.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/202.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/203.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/204.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/205.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/206.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/207.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/208.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/209.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/210.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/211.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/212.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/213.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/214.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/215.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/216.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/217.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/218.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/219.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/220.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/221.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/222.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/223.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/224.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/225.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/226.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/227.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/228.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/229.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/230.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/231.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/232.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/233.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/234.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/235.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/236.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/237.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/238.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/239.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/240.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/241.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/242.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/243.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/244.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/245.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/246.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/247.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/248.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/249.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/250.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/251.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/252.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/253.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/254.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/255.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/256.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/257.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/258.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/259.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/260.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/261.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/262.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/263.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/264.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/265.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/266.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/267.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/268.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/269.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/270.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/271.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/272.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/273.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/274.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/275.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/276.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/277.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/278.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/279.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/280.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/281.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/282.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/283.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/284.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/285.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/286.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/287.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/288.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/289.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/290.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/291.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/292.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/293.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/294.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/295.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/296.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/297.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/298.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/299.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/300.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/301.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/302.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/303.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/304.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/305.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/306.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/307.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/308.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/309.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/310.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/311.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/312.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/313.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/314.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/315.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/316.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/317.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/318.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/319.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/320.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/321.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/322.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/323.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/324.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/325.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/326.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/327.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/328.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/329.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/330.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/331.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/332.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/333.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/334.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/335.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/336.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/337.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/338.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/339.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/340.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/341.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/342.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/343.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/344.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/345.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/346.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/347.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/348.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/349.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/350.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/351.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/352.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/353.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/354.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/355.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/356.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/357.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/358.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/359.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/360.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/361.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/362.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/363.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/364.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/365.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/366.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/367.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/368.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/369.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/370.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/371.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/372.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/373.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/374.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/375.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/376.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/377.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/378.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/379.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/380.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/381.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/382.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/383.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/384.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/385.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/386.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/387.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/388.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/389.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/390.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/391.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/392.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/393.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/394.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/395.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/396.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/397.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/398.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/399.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/400.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/401.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/402.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/403.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/404.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/405.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/406.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/407.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/408.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/409.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/410.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/411.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/412.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/413.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/414.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/415.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/416.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/417.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/418.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/419.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/420.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/421.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/422.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/423.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/424.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/425.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/426.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/427.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/428.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/429.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/430.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/431.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/432.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/433.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/434.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/435.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/436.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/437.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/438.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/439.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/440.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/441.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/442.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/443.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/444.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/445.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/446.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/447.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/448.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/449.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/450.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/451.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/452.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/453.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/454.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/455.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/456.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/457.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/458.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/459.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/460.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/461.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/462.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/463.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/464.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/465.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/466.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/467.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/468.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/469.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/470.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/471.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/472.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/473.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/474.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/475.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/476.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/477.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/478.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/479.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/480.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/481.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/482.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/483.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/484.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/485.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/486.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/487.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/488.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/489.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/490.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/491.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/492.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/493.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/494.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/495.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/496.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/497.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/498.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/499.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/500.jpg
# ...
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/817.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/818.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/819.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/820.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/821.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/822.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/823.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/824.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/825.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/826.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/827.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/828.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/829.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/830.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/831.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/832.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/833.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/834.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/835.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/836.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/837.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/838.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/839.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/840.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/841.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/842.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/843.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/844.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/845.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/846.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/847.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/848.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/849.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/850.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/851.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/852.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/853.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/854.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/855.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/856.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/857.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/858.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/859.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/860.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/861.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/862.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/863.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/864.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/865.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/866.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/867.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/868.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/869.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/870.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/871.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/872.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/873.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/874.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/875.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/876.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/877.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/878.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/879.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/880.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/881.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/882.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/883.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/884.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/885.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/886.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/887.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/888.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/889.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/890.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/891.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/892.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/893.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/894.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/895.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/896.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/897.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/898.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/899.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/900.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/901.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/902.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/903.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/904.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/905.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/906.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/907.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/908.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/909.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/910.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/911.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/912.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/913.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/914.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/915.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/916.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/917.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/918.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/919.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/920.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/921.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/922.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/923.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/924.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/925.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/926.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/927.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/928.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/929.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/930.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/931.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/932.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/933.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/934.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/935.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/936.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/937.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/938.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/939.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/940.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/941.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/942.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/943.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/944.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/945.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/946.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/947.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/948.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/949.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/950.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/951.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/952.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/953.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/954.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/955.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/956.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/957.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/958.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/959.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/960.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/961.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/962.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/963.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/964.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/965.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/966.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/967.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/968.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/969.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/970.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/971.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/972.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/973.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/974.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/975.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/976.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/977.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/978.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/979.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/980.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/981.jpg
# /content/drive/MyDrive/Tave 16기 심화프로젝트/TAVE 16th/data/total_thumbnail_face_labeling_0.2/982.jpg
